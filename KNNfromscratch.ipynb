# %%
import numpy as np
import pandas as pd
import scipy
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from math import sqrt

from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/content/data.csv")

# %%
df.diagnosis = df.diagnosis.map({"M":1,"B":0})
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
X_train , X_test , y_train , y_test = train_test_split(df.iloc[:,1:31],df.iloc[:,1],test_size=0.2)

# %%
X_train , X_valid , y_train , y_valid = train_test_split(X_train,y_train,test_size=0.1)

# %%
y_train = np.reshape(y_train.values,(-1,1))
y_test = np.reshape(y_test.values,(-1,1))
y_valid = np.reshape(y_valid.values,(-1,1))

# %%
print(y_train)

# %%
def euclidean_distance(v1,v2):
    v1,v2 = np.array(v1),np.array(v2)
    distance = 0
    for i in range(len(v1)):
        distance += (v1[i]-v2[i])**2
    return np.sqrt(distance)

# %%
def measures(yhat,test):
    
    TP , TN , FP , FN = 0.0001 , 0.0001 , 0.0001 , 0.0001
    
    
    for ypred, y in zip(yhat, test):
        if ypred==1 and y==1:
            TP+=1
        elif ypred==1 and y==0:
            FP+=1
        elif ypred==0 and y==1:
            FN+=1
        elif ypred==0 and y==0:
            TN+=1
                
    Accuracy = (TP + TN)/len(yhat)
    
    Precision = TP / (TP + FP)
    
    Recall = TP / (TP + FN )
    
    f_measure = (2*Precision*Recall)/(Precision + Recall)
    
    print("Accuracy :",Accuracy)
    print("Precision :",Precision)
    print("Recall :",Recall)
    print("F-Measure :",f_measure)
    return f_measure

# %%
def knnAlgo(k,train_x,train_y,test_x,test_y):
    i = 0
    j = 0
    ypred = []
    train_x = list(train_x.values)
    train_y = list(train_y)
    test_x=list(test_x.values)
    test_y =list(test_y)
   
    for i in range(len(test_x)):
        c1 = 0
        c0 = 0
        distance = []
        for j in range(len(train_x)):
            di = euclidean_distance(test_x[i],train_x[j])
            distance.append((train_x[j],di,train_y[j]))
            
        
        distance.sort(key=lambda x:x[1])
        N = distance[:k]
      
    
        for l in range(k):
            if N[l][2]==1:
                c1 = c1+1 
            if N[l][2]==0:
                c0 = c0+1 
            
        if c0>c1:
            ypred.append(0)
        else:
            ypred.append(1)  
        
    #print (ypred)
    f = measures(ypred,test_y)
    return f

# %%
K = [1, 3, 5, 7, 9, 11]
f =[]

for k in K:
    print ("\n K = ",k)
    fmeasure=knnAlgo(k,X_train, y_train, X_valid, y_valid)
    f.append(fmeasure)
    

K_VALUE = K[f.index(max(f))]
print("\nMAXIMUM F MEASURE = ",max(f),"for K = ",K_VALUE)
# Out:
#  K =  1
# Accuracy : 0.9130478260869566
# Precision : 0.8666617778429621
# Recall : 0.8666617778429621
# F-Measure : 0.8666617778429621
#
#  K =  3
# Accuracy : 0.8913086956521739
# Precision : 0.8571377551749261
# Recall : 0.7999960000533326
# F-Measure : 0.8275816885284342
#
#  K =  5
# Accuracy : 0.9130478260869566
# Precision : 0.9230704143013184
# Recall : 0.7999960000533326
# F-Measure : 0.857137755174926
#
#  K =  7
# Accuracy : 0.8913086956521739
# Precision : 0.916659722337961
# Recall : 0.7333302222637031
# F-Measure : 0.8148101509607265
#
#  K =  9
# Accuracy : 0.8913086956521739
# Precision : 0.916659722337961
# Recall : 0.7333302222637031
# F-Measure : 0.8148101509607265
#
#  K =  11
# Accuracy : 0.8913086956521739
# Precision : 0.916659722337961
# Recall : 0.7333302222637031
# F-Measure : 0.8148101509607265
#
# MAXIMUM F MEASURE =  0.8666617778429621 for K =  1

# %%
fmeasure=knnAlgo(K_VALUE,X_train, y_train, X_test, y_test)
fmeasure
# Out:
# Accuracy : 0.9298263157894737
# Precision : 0.8749981250093749
# Recall : 0.9210504155241287
# F-Measure : 0.8974338593135419
# 0.8974338593135419
